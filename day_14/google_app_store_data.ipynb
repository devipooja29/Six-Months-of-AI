# %% [markdown]
# # *Data Cleaning of Google App Store Data*

# %% [markdown]
# Author: Pooja D \
# Date: 04/May/2024 \
# [Dataset Link](https://www.kaggle.com/datasets/lava18/google-play-store-apps/)

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('googleplaystore.csv')
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             1
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               1
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
df[df['Category'].isnull()]
# Out:
#                                            App Category  Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      NaN     1.9       19
#
#        Size Installs  Type Price Content Rating Genres       Last Updated  \
# 10472  3.0M   1,000+  Free     0       Everyone    NaN  February 11, 2018
#
#       Current Ver Android Ver
# 10472      1.0.19  4.0 and up

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION', nan],
#       dtype=object)

# %%
df[df['Category'] == 'PHOTOGRAPHY'].sort_values(by='Category')
# Out:
#                                                      App     Category  Rating  \
# 2801                            TouchNote: Cards & Gifts  PHOTOGRAPHY     4.1
# 6191                         Background Changer & Eraser  PHOTOGRAPHY     4.0
# 6184                                   Background Eraser  PHOTOGRAPHY     4.5
# 6178                             Change photo background  PHOTOGRAPHY     3.8
# 6166                             Auto Background Changer  PHOTOGRAPHY     4.0
# ...                                                  ...          ...     ...
# 2909   Candy Camera - selfie, beauty camera, photo ed...  PHOTOGRAPHY     4.4
# 2908                                             Retrica  PHOTOGRAPHY     4.3
# 2907                       EyeEm - Camera & Photo Filter  PHOTOGRAPHY     4.2
# 2905               Camera MX - Free Photo & Video Camera  PHOTOGRAPHY     4.3
# 10740                                         PhotoFunia  PHOTOGRAPHY     4.3
#
#        Reviews                Size      Installs  Type Price Content Rating  \
# 2801     19232                 28M    1,000,000+  Free     0       Everyone
# 6191      2076                 11M      500,000+  Free     0           Teen
# 6184    267378                1.9M   10,000,000+  Free     0       Everyone
# 6178     28660                6.4M    5,000,000+  Free     0       Everyone
# 6166     35188                6.2M    1,000,000+  Free     0       Everyone
# ...        ...                 ...           ...   ...   ...            ...
# 2909   3368646  Varies with device  100,000,000+  Free     0       Everyone
# 2908   6120977  Varies with device  100,000,000+  Free     0       Everyone
# 2907    215343                 44M   10,000,000+  Free     0       Everyone
# 2905    244371  Varies with device   10,000,000+  Free     0       Everyone
# 10740   316378                4.4M   10,000,000+  Free     0       Everyone
#
#             Genres       Last Updated         Current Ver         Android Ver
# 2801   Photography     August 6, 2018               7.4.2          4.4 and up
# 6191   Photography       May 21, 2018                 2.5          4.1 and up
# 6184   Photography      July 11, 2015               1.4.6          4.0 and up
# 6178   Photography     March 21, 2018              1.0.12        4.0.3 and up
# 6166   Photography  February 22, 2018              1.0.11          3.2 and up
# ...            ...                ...                 ...                 ...
# 2909   Photography      July 16, 2018                4.47        4.0.3 and up
# 2908   Photography      June 28, 2018               6.1.0  Varies with device
# 2907   Photography      July 14, 2018               6.4.3        4.0.3 and up
# 2905   Photography       July 5, 2018  Varies with device  Varies with device
# 10740  Photography       June 3, 2017             4.0.7.0          2.3 and up
#
# [335 rows x 13 columns]

# %%
df['Category'] = df['Category'].fillna('PHOTOGRAPHY')

# %%
df['Category'].isnull().sum()
# Out:
# 0

# %%
df[df['Type'].isnull()]
# Out:
#                             App Category  Rating  Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN        0  Varies with device
#
#      Installs Type Price Content Rating    Genres   Last Updated  \
# 9148        0  NaN     0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver
# 9148  Varies with device  Varies with device

# %%
df['Type'] = df['Type'].fillna('Free')

# %%
df["Type"].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
df[df['Genres'].isnull()]
# Out:
#                                            App     Category  Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame  PHOTOGRAPHY     1.9       19
#
#        Size Installs  Type Price Content Rating Genres       Last Updated  \
# 10472  3.0M   1,000+  Free     0       Everyone    NaN  February 11, 2018
#
#       Current Ver Android Ver
# 10472      1.0.19  4.0 and up

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df['Genres'] = df['Genres'].fillna('photography')

# %%
df['Genres'].isnull().sum()
# Out:
# 0

# %%
df[df['Android Ver'].isnull()]
# Out:
#                          App         Category  Rating  Reviews  Size Installs  \
# 4453  [substratum] Vacuum: P  PERSONALIZATION     4.4      230   11M   1,000+
# 4490    Pi Dark [substratum]  PERSONALIZATION     4.5      189  2.1M  10,000+
#
#       Type  Price Content Rating           Genres    Last Updated Current Ver  \
# 4453  Paid  $1.49       Everyone  Personalization   July 20, 2018         4.4
# 4490  Free      0       Everyone  Personalization  March 27, 2018         1.1
#
#      Android Ver
# 4453         NaN
# 4490         NaN

# %%
df['App'].value_counts().get('[substratum] Vacuum: P', 0)
# Out:
# 1

# %%
df['App'].value_counts().get('Pi Dark [substratum]', 0)
# Out:
# 1

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.duplicated().sum()
# Out:
# 483

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (10358, 13)

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# # Numeric features in data
# 1.  Rating
# 2.  Reviews
# 3.  Size
# 4.  Installs
# 5.  Price

# %%
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1526
# 11M                    188
# 13M                    186
# 12M                    186
# 14M                    182
#                       ...
# 430k                     1
# 429k                     1
# 200k                     1
# 460k                     1
# 619k                     1
# Name: count, Length: 461, dtype: int64

# %%
def convert_to_numeric(size):
    if 'M' in size:
        return size.replace('M', '')
    elif 'K' in size:
        return str(round(float(size.replace('K', '')) / 1024, 1))

# Apply the function to the 'Size' column
df['Size'] = df['Size'].apply(convert_to_numeric)

print(df['Size'])
# Out:
# 0          19
# 1          14
# 2         8.7
# 3          25
# 4         2.8
#          ...
# 10836      53
# 10837     3.6
# 10838     9.5
# 10839    None
# 10840      19
# Name: Size, Length: 10358, dtype: object

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df['Size'].unique()
# Out:
# array(['19', '14', '8.7', '25', '2.8', '5.6', '29', '33', '3.1', '28',
#        '12', '20', '21', '37', '2.7', '5.5', '17', '39', '31', '4.2',
#        '7.0', '23', '6.0', '6.1', '4.6', '9.2', '5.2', '11', '24', None,
#        '9.4', '15', '10', '1.2', '26', '8.0', '7.9', '56', '57', '35',
#        '54', '3.6', '5.7', '8.6', '2.4', '27', '2.5', '16', '3.4', '8.9',
#        '3.9', '2.9', '38', '32', '5.4', '18', '1.1', '2.2', '4.5', '9.8',
#        '52', '9.0', '6.7', '30', '2.6', '7.1', '3.7', '22', '7.4', '6.4',
#        '3.2', '8.2', '9.9', '4.9', '9.5', '5.0', '5.9', '13', '73', '6.8',
#        '3.5', '4.0', '2.3', '7.2', '2.1', '42', '7.3', '9.1', '55', '6.5',
#        '1.5', '7.5', '51', '41', '48', '8.5', '46', '8.3', '4.3', '4.7',
#        '3.3', '40', '7.8', '8.8', '6.6', '5.1', '61', '66', '8.4', '44',
#        '1.6', '6.2', '53', '1.4', '3.0', '5.8', '3.8', '9.6', '45', '63',
#        '49', '77', '4.4', '4.8', '70', '6.9', '9.3', '10.0', '8.1', '36',
#        '84', '97', '2.0', '1.9', '1.8', '5.3', '47', '76', '7.6', '59',
#        '9.7', '78', '72', '43', '7.7', '6.3', '34', '93', '65', '79',
#        '100', '58', '50', '68', '64', '67', '60', '94', '99', '95', '80',
#        '1.7', '74', '62', '69', '75', '98', '85', '82', '96', '87', '71',
#        '86', '91', '81', '92', '83', '88', '1.3', '4.1', '89', '90',
#        '1.0'], dtype=object)

# %%
df['Size'] = df['Size'].replace('None', 0)

# %%
df['Size'] = df['Size'].fillna('0')

# %%
df['Size'].unique()
# Out:
# array(['19', '14', '8.7', '25', '2.8', '5.6', '29', '33', '3.1', '28',
#        '12', '20', '21', '37', '2.7', '5.5', '17', '39', '31', '4.2',
#        '7.0', '23', '6.0', '6.1', '4.6', '9.2', '5.2', '11', '24', '0',
#        '9.4', '15', '10', '1.2', '26', '8.0', '7.9', '56', '57', '35',
#        '54', '3.6', '5.7', '8.6', '2.4', '27', '2.5', '16', '3.4', '8.9',
#        '3.9', '2.9', '38', '32', '5.4', '18', '1.1', '2.2', '4.5', '9.8',
#        '52', '9.0', '6.7', '30', '2.6', '7.1', '3.7', '22', '7.4', '6.4',
#        '3.2', '8.2', '9.9', '4.9', '9.5', '5.0', '5.9', '13', '73', '6.8',
#        '3.5', '4.0', '2.3', '7.2', '2.1', '42', '7.3', '9.1', '55', '6.5',
#        '1.5', '7.5', '51', '41', '48', '8.5', '46', '8.3', '4.3', '4.7',
#        '3.3', '40', '7.8', '8.8', '6.6', '5.1', '61', '66', '8.4', '44',
#        '1.6', '6.2', '53', '1.4', '3.0', '5.8', '3.8', '9.6', '45', '63',
#        '49', '77', '4.4', '4.8', '70', '6.9', '9.3', '10.0', '8.1', '36',
#        '84', '97', '2.0', '1.9', '1.8', '5.3', '47', '76', '7.6', '59',
#        '9.7', '78', '72', '43', '7.7', '6.3', '34', '93', '65', '79',
#        '100', '58', '50', '68', '64', '67', '60', '94', '99', '95', '80',
#        '1.7', '74', '62', '69', '75', '98', '85', '82', '96', '87', '71',
#        '86', '91', '81', '92', '83', '88', '1.3', '4.1', '89', '90',
#        '1.0'], dtype=object)

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df['Size'] = pd.to_numeric(df['Size'], errors='coerce')

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size              float64
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.sample(10)
# Out:
#                                    App         Category  Rating  Reviews  \
# 7319                    CG Backgrounds           FAMILY     4.0        8
# 6050     Millionaire : Who want to be?             GAME     4.4     4396
# 5696                          AV Tools            TOOLS     4.4      631
# 1041                     mobLee Events           EVENTS     NaN       11
# 8079                        Ambient CX         BUSINESS     NaN        0
# 5855     Ay Vamos - PJ. Balvin - Piano             GAME     NaN        0
# 5759          Square Analog Clock AW-7            TOOLS     4.2      294
# 3413          Waterfall Live Wallpaper  PERSONALIZATION     4.1   112977
# 4492  The Q - Live Trivia Game Network             GAME     2.7     1486
# 6503                BNCR Token Celular          FINANCE     3.7      913
#
#       Size     Installs  Type Price Content Rating           Genres  \
# 7319   3.6         500+  Free     0       Everyone    Entertainment
# 6050  40.0     100,000+  Free     0       Everyone           Trivia
# 5696   0.0     100,000+  Free     0       Everyone            Tools
# 1041  11.0       5,000+  Free     0       Everyone           Events
# 8079   7.5           5+  Free     0       Everyone         Business
# 5855  29.0           5+  Free     0       Everyone           Arcade
# 5759   3.0      50,000+  Free     0       Everyone            Tools
# 3413  13.0  10,000,000+  Free     0       Everyone  Personalization
# 4492  14.0     100,000+  Free     0       Everyone           Trivia
# 6503   0.0     100,000+  Free     0       Everyone          Finance
#
#             Last Updated         Current Ver         Android Ver
# 7319       June 19, 2018                 8.1        4.0.3 and up
# 6050      April 12, 2017                 1.5          2.3 and up
# 5696  September 22, 2016  Varies with device  Varies with device
# 1041        May 30, 2018          3.05.30.16          4.1 and up
# 8079         May 9, 2017                 1.0        2.3.3 and up
# 5855        July 9, 2018                 1.0          4.1 and up
# 5759      March 10, 2018                 2.0          4.3 and up
# 3413        May 22, 2018                 3.6          4.1 and up
# 4492      August 3, 2018               2.4.8          5.0 and up
# 6503       July 20, 2012                 1.0          1.5 and up

# %%
df['Price'] = pd.to_numeric(df['Price'].str.replace('$', ''))

# %%
df['Price'].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,   1.2 ,   1.04])

# %%
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
df['Installs'] = pd.to_numeric(df['Installs'].str.replace('+', '').str.replace(',', ''))

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size              float64
# Installs            int64
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df.to_csv('cleaned.csv')

# %%
df['Size'].unique()
# Out:
# array([ 19. ,  14. ,   8.7,  25. ,   2.8,   5.6,  29. ,  33. ,   3.1,
#         28. ,  12. ,  20. ,  21. ,  37. ,   2.7,   5.5,  17. ,  39. ,
#         31. ,   4.2,   7. ,  23. ,   6. ,   6.1,   4.6,   9.2,   5.2,
#         11. ,  24. ,   0. ,   9.4,  15. ,  10. ,   1.2,  26. ,   8. ,
#          7.9,  56. ,  57. ,  35. ,  54. ,   3.6,   5.7,   8.6,   2.4,
#         27. ,   2.5,  16. ,   3.4,   8.9,   3.9,   2.9,  38. ,  32. ,
#          5.4,  18. ,   1.1,   2.2,   4.5,   9.8,  52. ,   9. ,   6.7,
#         30. ,   2.6,   7.1,   3.7,  22. ,   7.4,   6.4,   3.2,   8.2,
#          9.9,   4.9,   9.5,   5. ,   5.9,  13. ,  73. ,   6.8,   3.5,
#          4. ,   2.3,   7.2,   2.1,  42. ,   7.3,   9.1,  55. ,   6.5,
#          1.5,   7.5,  51. ,  41. ,  48. ,   8.5,  46. ,   8.3,   4.3,
#          4.7,   3.3,  40. ,   7.8,   8.8,   6.6,   5.1,  61. ,  66. ,
#          8.4,  44. ,   1.6,   6.2,  53. ,   1.4,   3. ,   5.8,   3.8,
#          9.6,  45. ,  63. ,  49. ,  77. ,   4.4,   4.8,  70. ,   6.9,
#          9.3,   8.1,  36. ,  84. ,  97. ,   2. ,   1.9,   1.8,   5.3,
#         47. ,  76. ,   7.6,  59. ,   9.7,  78. ,  72. ,  43. ,   7.7,
#          6.3,  34. ,  93. ,  65. ,  79. , 100. ,  58. ,  50. ,  68. ,
#         64. ,  67. ,  60. ,  94. ,  99. ,  95. ,  80. ,   1.7,  74. ,
#         62. ,  69. ,  75. ,  98. ,  85. ,  82. ,  96. ,  87. ,  71. ,
#         86. ,  91. ,  81. ,  92. ,  83. ,  88. ,   1.3,   4.1,  89. ,
#         90. ,   1. ])

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df = df.rename(columns={'Size': 'Size (Mbs)'})
df = df.rename(columns={'Price': 'Price ($)'})

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size (Mbs)', 'Installs',
#        'Type', 'Price ($)', 'Content Rating', 'Genres', 'Last Updated',
#        'Current Ver', 'Android Ver'],
#       dtype='object')

# %%
df = df.dropna(subset=['Rating'])

# %%
df.shape
# Out:
# (8893, 13)

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size (Mbs)        0
# Installs          0
# Type              0
# Price ($)         0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       4
# Android Ver       2
# dtype: int64

# %%
df = df.dropna(subset=['Current Ver'])
df = df.dropna(subset=['Android Ver'])

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size (Mbs)        0
# Installs          0
# Type              0
# Price ($)         0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df.sample(34)
# Out:
#                                                      App            Category  \
# 6270                                   Sisense Mobile BI            BUSINESS
# 10114                            Hey That's Pretty Good!               TOOLS
# 3180                      Cheap Flights & Hotels momondo    TRAVEL_AND_LOCAL
# 10058                            Moonlight GO Weather EX             WEATHER
# 1037                         KudaGo - things to do in NY              EVENTS
# 7069                           Restaurantführer Südbaden    TRAVEL_AND_LOCAL
# 6001                                bd's Mongolian Grill           LIFESTYLE
# 4297                        Kpop Music Quiz (K-pop Game)              FAMILY
# 5038                                             AF Link  NEWS_AND_MAGAZINES
# 2962                                          MLB At Bat              SPORTS
# 2704                               Extreme Coupon Finder            SHOPPING
# 7767                                Deck Analyzer for CR               TOOLS
# 4446                                     The Maze Runner                GAME
# 8780                           Dr. Panda's Swimming Pool              FAMILY
# 326    Buff Thun - Daily Free Webtoon / Comics / Web ...              COMICS
# 1757                                          slither.io                GAME
# 3600                     How do I take care of my child?           PARENTING
# 4864                                       Angry Birds 2              FAMILY
# 19                                          ibis Paint X      ART_AND_DESIGN
# 6127                                            BG Score              SPORTS
# 4304                                     K-Otic Universe              FAMILY
# 7908                            Cyprus CU Mobile Banking             FINANCE
# 4030                                     100+ C Programs              FAMILY
# 10593                           Discovery Church Florida           LIFESTYLE
# 1710                                   My Talking Angela                GAME
# 6793                                       Autool BT-BOX               TOOLS
# 4954    Adblock Plus for Samsung Internet - Browse safe.       COMMUNICATION
# 6121                              Virtual Boyfriend Chat              FAMILY
# 6958                        bitcoin exchange bx thailand             FINANCE
# 1849                                 MARVEL Strike Force                GAME
# 5358                                          I am Rich!             FINANCE
# 566           Millionaire Match: Rich Singles Dating App              DATING
# 8676                     DP and Status for WhatsApp 2018              SOCIAL
# 995                                       My Talking Pet       ENTERTAINMENT
#
#        Rating  Reviews  Size (Mbs)   Installs  Type  Price ($) Content Rating  \
# 6270      4.9       23        28.0       1000  Free       0.00       Everyone
# 10114     4.6      222        10.0      10000  Free       0.00       Everyone
# 3180      4.2    42546        24.0    5000000  Free       0.00       Everyone
# 10058     4.2    11510         3.5    1000000  Free       0.00       Everyone
# 1037      4.4     4298         4.4     100000  Free       0.00       Everyone
# 7069      4.1       46        12.0       1000  Free       0.00       Everyone
# 6001      4.2      120        14.0      10000  Free       0.00       Everyone
# 4297      4.2     6418        59.0     100000  Free       0.00       Everyone
# 5038      4.7      210        18.0      10000  Free       0.00       Everyone
# 2962      4.2    82882         0.0    5000000  Free       0.00       Everyone
# 2704      4.1    11798         0.0    1000000  Free       0.00       Everyone
# 7767      4.2     2630        18.0     100000  Free       0.00       Everyone
# 4446      4.0   428268        22.0   10000000  Free       0.00       Everyone
# 8780      4.4     2311         9.3     100000  Paid       1.99       Everyone
# 326       4.5     9952        38.0     500000  Free       0.00   Everyone 10+
# 1757      4.4  5234810         0.0  100000000  Free       0.00       Everyone
# 3600      4.8      190         6.8     100000  Free       0.00       Everyone
# 4864      4.6  3881752        57.0  100000000  Free       0.00       Everyone
# 19        4.6   224399        31.0   10000000  Free       0.00       Everyone
# 6127      2.6       64         1.6      10000  Free       0.00       Everyone
# 4304      4.9       55        40.0       1000  Free       0.00       Everyone
# 7908      3.4      295         0.0      10000  Free       0.00       Everyone
# 4030      4.2       20         1.6       5000  Free       0.00       Everyone
# 10593     4.7       40         8.0       1000  Free       0.00           Teen
# 1710      4.5  9881908        99.0  100000000  Free       0.00       Everyone
# 6793      3.5        4        17.0        500  Free       0.00       Everyone
# 4954      4.0     8769         2.1    1000000  Free       0.00       Everyone
# 6121      2.4      407         0.0      50000  Free       0.00     Mature 17+
# 6958      2.9       19         2.2       5000  Free       0.00       Everyone
# 1849      4.3   165928        91.0    5000000  Free       0.00           Teen
# 5358      3.8       93        22.0       1000  Paid     399.99       Everyone
# 566       3.9      853        27.0     100000  Free       0.00     Mature 17+
# 8676      4.5      787         6.9     100000  Free       0.00       Everyone
# 995       4.6     6238         0.0     100000  Paid       4.99       Everyone
#
#                     Genres        Last Updated         Current Ver  \
# 6270              Business      April 30, 2018               2.4.1
# 10114                Tools       July 29, 2016               4.2.0
# 3180        Travel & Local      April 25, 2018               7.6.5
# 10058              Weather     August 28, 2014                 1.4
# 1037                Events      April 27, 2017               2.2.2
# 7069        Travel & Local    January 11, 2017               2.0.0
# 6001             Lifestyle   February 23, 2018               1.5.1
# 4297                Casual         May 8, 2017                 1.3
# 5038      News & Magazines        May 31, 2018           v4.29.0.9
# 2962                Sports       July 30, 2018  Varies with device
# 2704              Shopping        May 10, 2018  Varies with device
# 7767                 Tools    February 2, 2017               1.3.0
# 4446                Action  September 14, 2015               1.8.1
# 8780   Casual;Pretend Play    January 15, 2015                1.01
# 326                 Comics       July 31, 2018               4.3.0
# 1757                Action   November 14, 2017  Varies with device
# 3600             Parenting       June 24, 2018                 1.5
# 4864                Casual       July 26, 2018              2.21.1
# 19            Art & Design       July 30, 2018               5.5.4
# 6127                Sports       July 26, 2017                 2.1
# 4304                Puzzle      August 3, 2018                 108
# 7908               Finance   February 13, 2018               5.3.4
# 4030             Education     January 3, 2017                 1.0
# 10593            Lifestyle       June 25, 2018               3.8.0
# 1710                Casual        July 3, 2018            3.7.2.51
# 6793                 Tools        May 12, 2018               1.0.1
# 4954         Communication       April 5, 2018               1.1.4
# 6121         Entertainment      April 11, 2017                 1.0
# 6958               Finance       June 26, 2017                 1.6
# 1849          Role Playing       July 31, 2018               1.4.0
# 5358               Finance   December 11, 2017                 1.0
# 566                 Dating       July 30, 2018               6.4.6
# 8676                Social   February 17, 2018               2.4.2
# 995          Entertainment       June 30, 2018  Varies with device
#
#               Android Ver
# 6270           4.1 and up
# 10114          2.3 and up
# 3180           4.4 and up
# 10058          2.2 and up
# 1037           4.0 and up
# 7069           4.0 and up
# 6001           4.1 and up
# 4297           4.1 and up
# 5038           4.4 and up
# 2962   Varies with device
# 2704   Varies with device
# 7767           4.1 and up
# 4446           2.3 and up
# 8780           4.0 and up
# 326            4.1 and up
# 1757           2.3 and up
# 3600           4.0 and up
# 4864           4.1 and up
# 19             4.1 and up
# 6127         4.0.3 and up
# 4304           4.1 and up
# 7908           4.4 and up
# 4030           4.0 and up
# 10593          4.1 and up
# 1710           4.1 and up
# 6793           4.3 and up
# 4954           5.0 and up
# 6121           2.2 and up
# 6958           4.4 and up
# 1849           4.4 and up
# 5358           4.1 and up
# 566            4.1 and up
# 8676         4.0.3 and up
# 995    Varies with device

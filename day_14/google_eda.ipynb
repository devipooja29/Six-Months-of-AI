# %% [markdown]
# # EDA on Google App Store Data

# %% [markdown]
# Dataset Link (https://www.kaggle.com/datasets/lava18/google-play-store-apps/)

# %%
# Import libraries
import pandas as pd
# import ydata_profiling as yd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read data
df = pd.read_csv('googleplaystore.csv')

# %%
# # Apply ydataprofiling
# profile = yd.ProfileReport(df)
# profile.to_file('googleplaystoreanalysis.html')

# %%
# Analyze data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df.sample(30)
# Out:
#                                                     App             Category  \
# 2369                             Tarascon Pharmacopoeia              MEDICAL
# 5802                                        The Vikings                 GAME
# 5337                     We're Working Out - Al Kavadlo   HEALTH_AND_FITNESS
# 4190                                  H*nest Meditation            LIFESTYLE
# 5174                                 Forest Crossing AH              MEDICAL
# 5884                                       Alphabet A-Z               FAMILY
# 10654                       Wallpapers FN Herstal FNP 9      PERSONALIZATION
# 2969                               kicker football news               SPORTS
# 2627                     Badoo - Free Chat & Dating App               SOCIAL
# 7619                          Best Park in the Universe                 GAME
# 7017                     Bingo by IGG: Top Bingo+Slots!                 GAME
# 8957                               DV Lottery Simulator               FAMILY
# 10632                               Florida Tech Mobile               FAMILY
# 6921                                    Skull Widget BW      PERSONALIZATION
# 1848                                 The Sims™ FreePlay                 GAME
# 3536                                    Note Everything         PRODUCTIVITY
# 10495                        HD Themes Toyota Cruiser70      PERSONALIZATION
# 886                                  Amazon Prime Video        ENTERTAINMENT
# 2499                     ScriptSave WellRx Rx Discounts              MEDICAL
# 6426                               OTOME of Ikemen cafe               FAMILY
# 8114                                    CY Spray nozzle  BOOKS_AND_REFERENCE
# 7850                                 Quiz CS:GO players                 GAME
# 5528                                     Knightfall™ AR               FAMILY
# 8517                          Download Accelerator Plus                TOOLS
# 6973                     Limbo PC Emulator QEMU ARM x86                TOOLS
# 5448                          AP Mobile - Breaking News   NEWS_AND_MAGAZINES
# 10299                                        FD CANNECT                TOOLS
# 4352   Mobizen Screen Recorder for LG - Record, Capture        VIDEO_PLAYERS
# 1716                              Candy Crush Soda Saga                 GAME
# 1212          SarashpazPapion (Cooking with Chef Bowls)       FOOD_AND_DRINK
#
#        Rating  Reviews                Size      Installs  Type  Price  \
# 2369      4.4      275                5.8M       10,000+  Free      0
# 5802      4.4    15806                 42M    1,000,000+  Free      0
# 5337      4.3      979  Varies with device       50,000+  Free      0
# 4190      4.9      145                 48M        5,000+  Paid  $1.99
# 5174      NaN        0                 29M           10+  Free      0
# 5884      3.9      306  Varies with device      100,000+  Free      0
# 10654     NaN        0                 11M            1+  Free      0
# 2969      4.3    56270                 15M    5,000,000+  Free      0
# 2627      4.3  3781770  Varies with device  100,000,000+  Free      0
# 7619      4.3     3904                5.5M       10,000+  Paid  $2.99
# 7017      4.7   183343                 20M    5,000,000+  Free      0
# 8957      4.6       13                1.3M        1,000+  Free      0
# 10632     3.8       87                5.4M        5,000+  Free      0
# 6921      4.5        4                1.7M           10+  Free      0
# 1848      4.3   931595                 31M   10,000,000+  Free      0
# 3536      4.4    57033  Varies with device    5,000,000+  Free      0
# 10495     NaN        0                 15M          100+  Free      0
# 886       4.2   411683                 24M   50,000,000+  Free      0
# 2499      3.8      700                 37M      100,000+  Free      0
# 6426      4.5     1318                 24M       50,000+  Free      0
# 8114      NaN        0                3.3M           10+  Free      0
# 7850      4.4      460                 31M       50,000+  Free      0
# 5528      4.2      254                 25M       10,000+  Free      0
# 8517      4.2    43677  Varies with device    1,000,000+  Free      0
# 6973      4.2    13005                9.7M    1,000,000+  Free      0
# 5448      4.5    76616                4.6M    1,000,000+  Free      0
# 10299     NaN        1                 75M            1+  Free      0
# 4352      4.5    58820                 37M    1,000,000+  Free      0
# 1716      4.4  6198880                 67M  100,000,000+  Free      0
# 1212      4.8     1250                 13M       50,000+  Free      0
#
#       Content Rating                   Genres        Last Updated  \
# 2369    Everyone 10+                  Medical      March 16, 2018
# 5802            Teen                   Arcade        June 6, 2018
# 5337        Everyone         Health & Fitness   December 24, 2017
# 4190      Mature 17+                Lifestyle       April 7, 2016
# 5174        Everyone                  Medical      April 12, 2018
# 5884        Everyone                   Casual      April 17, 2014
# 10654           Teen          Personalization      April 12, 2018
# 2969        Everyone                   Sports      August 3, 2018
# 2627      Mature 17+                   Social      August 2, 2018
# 7619    Everyone 10+                   Action  September 10, 2014
# 7017            Teen                   Casino        May 28, 2018
# 8957        Everyone            Entertainment    October 20, 2016
# 10632       Everyone                Education  September 13, 2016
# 6921        Everyone          Personalization   February 28, 2018
# 1848            Teen               Simulation       July 16, 2018
# 3536        Everyone             Productivity    October 18, 2016
# 10495           Teen          Personalization     October 3, 2016
# 886             Teen            Entertainment      August 2, 2018
# 2499        Everyone                  Medical       June 21, 2018
# 6426            Teen               Simulation       March 5, 2018
# 8114        Everyone        Books & Reference      August 3, 2017
# 7850        Everyone                   Trivia       June 23, 2018
# 5528            Teen                 Strategy      March 17, 2018
# 8517        Everyone                    Tools     August 30, 2017
# 6973        Everyone                    Tools    January 21, 2018
# 5448    Everyone 10+         News & Magazines        May 25, 2017
# 10299       Everyone                    Tools       July 31, 2018
# 4352        Everyone  Video Players & Editors      April 26, 2018
# 1716        Everyone                   Casual       July 10, 2018
# 1212        Everyone             Food & Drink       July 28, 2018
#
#                                    Current Ver         Android Ver
# 2369                               3.16.4.1669          4.4 and up
# 5802                                     1.0.7          4.1 and up
# 5337                        Varies with device  Varies with device
# 4190                                       1.0        4.0.3 and up
# 5174                               300000.1.01        4.0.3 and up
# 5884                        Varies with device  Varies with device
# 10654                                      1.0          4.1 and up
# 2969                                     5.4.2          5.0 and up
# 2627                        Varies with device  Varies with device
# 7619                                     1.2.1          4.0 and up
# 7017                                     1.5.1          2.3 and up
# 8957                                       1.1          4.1 and up
# 10632                                      5.2          4.1 and up
# 6921                                       1.1          4.4 and up
# 1848                                    5.39.1        4.0.3 and up
# 3536                                    4.2.11  Varies with device
# 10495                                      1.0        2.3.3 and up
# 886                              3.0.231.18141          4.1 and up
# 2499                                     3.3.0          4.4 and up
# 6426                                    1.0.21          4.1 and up
# 8114                                   1.01.00        4.0.3 and up
# 7850                                       4.2        4.0.3 and up
# 5528                                       1.0          7.0 and up
# 8517                                  20170828  Varies with device
# 6973   no_update_signal.2_9_1_arm-x86_64-alpha          4.2 and up
# 5448                                     4.4.3          4.0 and up
# 10299                                        3          8.0 and up
# 4352                                   3.5.1.8          4.4 and up
# 1716                                   1.118.4          4.1 and up
# 1212                                     3.2.7          4.1 and up

# %%
df.describe()
# Out:
#             Rating       Reviews
# count  9367.000000  1.084100e+04
# mean      4.191513  4.441119e+05
# std       0.515735  2.927629e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.800000e+01
# 50%       4.300000  2.094000e+03
# 75%       4.500000  5.476800e+04
# max       5.000000  7.815831e+07

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             1
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               1
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
df.sample(2)
# Out:
#                                App Category  Rating  Reviews  Size Installs  \
# 8605                     DN Driver   FAMILY     NaN        0  7.5M       5+
# 4613  Please, Don't Touch Anything   FAMILY     4.4     1771   46M  10,000+
#
#       Type  Price Content Rating     Genres    Last Updated Current Ver  \
# 8605  Free      0       Everyone  Education    June 9, 2018       1.0.2
# 4613  Paid  $4.99           Teen     Puzzle  April 20, 2016       1.1.0
#
#      Android Ver
# 8605  4.1 and up
# 4613  2.3 and up

# %% [markdown]
# # Numeric features in data
# 1.  Rating
# 2.  Reviews
# 3.  Size
# 4.  Installs
# 5.  Price

# %%
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 430k                     1
# 429k                     1
# 200k                     1
# 460k                     1
# 619k                     1
# Name: count, Length: 461, dtype: int64

# %%
df['Size'].isnull().sum()
# Out:
# 0

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             908
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Name: count, dtype: int64

# %%
df['Installs'].isnull().sum()
# Out:
# 0

# %%
df['Price'].value_counts()
# Out:
# Price
# 0         10041
# $0.99       148
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $19.90        1
# $1.75         1
# $14.00        1
# $4.85         1
# $1.04         1
# Name: count, Length: 92, dtype: int64

# %%
df['Price'].isnull().sum()
# Out:
# 0

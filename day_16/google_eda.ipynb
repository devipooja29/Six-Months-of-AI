# %% [markdown]
# # EDA on Google App Store Data

# %% [markdown]
# Dataset Link (https://www.kaggle.com/datasets/lava18/google-play-store-apps/)

# %%
# Import libraries
import pandas as pd
# import ydata_profiling as yd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read data
df = pd.read_csv('googleplaystore.csv')

# %%
# # Apply ydataprofiling
# profile = yd.ProfileReport(df)
# profile.to_file('googleplaystoreanalysis.html')

# %%
# Analyze data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df.sample(30)
# Out:
#                                                      App             Category  \
# 3893                                          4 in a Row                 GAME
# 1838                                  Star Wars ™: DIRTY                 GAME
# 3289                               Tiny Flashlight + LED                TOOLS
# 9673                        Masha and Bear: Cooking Dash               FAMILY
# 4498                                     Fossil Q Legacy            LIFESTYLE
# 2229                          Inside Out Thought Bubbles               FAMILY
# 9384                              Driving School 3D 2017               FAMILY
# 1398                      Weight Loss Tracker - RecStyle   HEALTH_AND_FITNESS
# 750                                            Brilliant            EDUCATION
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 3787                          ABC News - US & World News   NEWS_AND_MAGAZINES
# 1029   Quake & Volcanoes: 3D Globe of Volcanic Eruptions               EVENTS
# 2595              ooVoo Video Calls, Messaging & Stories               SOCIAL
# 3356                          3D Live Neon Weed Launcher      PERSONALIZATION
# 3891                               Create A Superhero HD               FAMILY
# 2682                                       Family Dollar             SHOPPING
# 6655                                     Woody's Bar-B-Q       FOOD_AND_DRINK
# 1044                   Arab Halls - For Wedding & Events               EVENTS
# 1950                                  Battlelands Royale                 GAME
# 9244                          AP Stamps and Registration  BOOKS_AND_REFERENCE
# 16          Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 7442                          Sir C J New Primary School               FAMILY
# 1727                                     Zombie Catchers                 GAME
# 10838                             Parkinson Exercices FR              MEDICAL
# 8870                                              PAY DT             BUSINESS
# 2138                                    Frozen Free Fall               FAMILY
# 9861                              Fitness & Bodybuilding   HEALTH_AND_FITNESS
# 5700                                  AV HD Video Player               FAMILY
# 5912                      Financial Calculator BA Chien.              FINANCE
# 2980                                           BBC Sport               SPORTS
#
#        Rating  Reviews                Size      Installs  Type  Price  \
# 3893      3.8     4257  Varies with device      500,000+  Free      0
# 1838      4.5    38207                 15M      100,000+  Paid  $9.99
# 3289      4.4  4254879  Varies with device  100,000,000+  Free      0
# 9673      4.3   151374                 54M   10,000,000+  Free      0
# 4498      2.6      680                 60M       50,000+  Free      0
# 2229      4.4   623398                 58M   10,000,000+  Free      0
# 9384      3.9     5075                 48M      500,000+  Free      0
# 1398      4.4    20547                5.7M    1,000,000+  Free      0
# 750       4.5    41185  Varies with device    1,000,000+  Free      0
# 6         3.8      178                 19M       50,000+  Free      0
# 3787      4.0    18976                 35M    1,000,000+  Free      0
# 1029      4.4      663                6.0M      100,000+  Free      0
# 2595      4.3  1157004                 34M   50,000,000+  Free      0
# 3356      4.5     1724                 21M      100,000+  Free      0
# 3891      3.3     8642                 19M      500,000+  Free      0
# 2682      4.3     2588                 21M    1,000,000+  Free      0
# 6655      3.7        3                 27M        1,000+  Free      0
# 1044      4.8       28                6.3M        1,000+  Free      0
# 1950      4.4   105620                 61M    1,000,000+  Free      0
# 9244      3.4       82                2.7M       10,000+  Free      0
# 16        4.7     3632                5.5M      500,000+  Free      0
# 7442      5.0        3                9.2M          100+  Free      0
# 1727      4.7   990586                 75M   10,000,000+  Free      0
# 10838     NaN        3                9.5M        1,000+  Free      0
# 8870      NaN        0                5.3M            1+  Free      0
# 2138      4.3  1574197                 37M   50,000,000+  Free      0
# 9861      4.6    95201                 61M    5,000,000+  Free      0
# 5700      3.8        6                 23M        1,000+  Free      0
# 5912      4.2       23                954k          500+  Paid  $3.99
# 2980      4.2    18678  Varies with device    1,000,000+  Free      0
#
#       Content Rating                     Genres        Last Updated  \
# 3893        Everyone                      Board        May 13, 2018
# 1838            Teen               Role Playing    October 19, 2015
# 3289        Everyone                      Tools        July 8, 2018
# 9673        Everyone   Role Playing;Brain Games        June 5, 2018
# 4498        Everyone                  Lifestyle  September 19, 2017
# 2229        Everyone         Puzzle;Brain Games     August 31, 2017
# 9384        Everyone                 Simulation       April 4, 2017
# 1398        Everyone           Health & Fitness   November 29, 2017
# 750         Everyone                  Education      August 3, 2018
# 6           Everyone               Art & Design      April 26, 2018
# 3787    Everyone 10+           News & Magazines        June 6, 2018
# 1029        Everyone                     Events    October 14, 2017
# 2595        Everyone                     Social    October 16, 2017
# 3356      Mature 17+            Personalization       June 26, 2018
# 3891            Teen                     Casual   December 30, 2017
# 2682        Everyone                   Shopping       July 23, 2018
# 6655        Everyone               Food & Drink       March 5, 2018
# 1044        Everyone                     Events        May 20, 2018
# 1950    Everyone 10+                     Action       July 16, 2018
# 9244        Everyone          Books & Reference      March 27, 2018
# 16          Everyone               Art & Design       July 31, 2018
# 7442        Everyone                  Education       July 25, 2018
# 1727        Everyone                     Action        May 24, 2018
# 10838       Everyone                    Medical    January 20, 2017
# 8870        Everyone                   Business    February 6, 2018
# 2138        Everyone  Puzzle;Action & Adventure       July 27, 2018
# 9861        Everyone           Health & Fitness        July 9, 2018
# 5700        Everyone              Entertainment    January 19, 2018
# 5912        Everyone                    Finance   December 14, 2016
# 2980        Everyone                     Sports      April 25, 2018
#
#               Current Ver         Android Ver
# 3893   Varies with device  Varies with device
# 1838                1.0.6          4.1 and up
# 3289   Varies with device  Varies with device
# 9673                1.2.7          4.1 and up
# 4498                1.0.1          4.4 and up
# 2229               1.22.0        4.0.3 and up
# 9384                2.1.5          3.0 and up
# 1398                3.2.7          4.1 and up
# 750    Varies with device  Varies with device
# 6                     1.1        4.0.3 and up
# 3787              3.19.11          5.0 and up
# 1029                1.1.3          4.1 and up
# 2595                4.2.1          4.3 and up
# 3356              5.34.10        4.0.3 and up
# 3891                4.0.4          2.3 and up
# 2682                2.4.0          4.1 and up
# 6655              1.01.03          4.1 and up
# 1044             8.0bld14          4.1 and up
# 1950                0.5.8          4.1 and up
# 9244                  2.0          3.0 and up
# 16                    3.1          4.1 and up
# 7442               1.0.10          4.0 and up
# 1727               1.0.27          4.1 and up
# 10838                 1.0          2.2 and up
# 8870                1.1.0          4.0 and up
# 2138                6.7.0          4.2 and up
# 9861                2.4.1          4.1 and up
# 5700                  1.0          4.4 and up
# 5912               1.9.10          3.0 and up
# 2980   Varies with device  Varies with device

# %%
df.describe()
# Out:
#             Rating       Reviews
# count  9367.000000  1.084100e+04
# mean      4.191513  4.441119e+05
# std       0.515735  2.927629e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.800000e+01
# 50%       4.300000  2.094000e+03
# 75%       4.500000  5.476800e+04
# max       5.000000  7.815831e+07

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             1
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               1
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
df.sample(2)
# Out:
#                                                    App         Category  \
# 4812  GO Launcher - 3D parallax Themes & HD Wallpapers  PERSONALIZATION
# 2763                                   Amazon Shopping         SHOPPING
#
#       Rating  Reviews                Size      Installs  Type Price  \
# 4812     4.5  7464996  Varies with device  100,000,000+  Free     0
# 2763     4.3   909204                 42M  100,000,000+  Free     0
#
#      Content Rating           Genres    Last Updated         Current Ver  \
# 4812       Everyone  Personalization  August 3, 2018  Varies with device
# 2763           Teen         Shopping   July 31, 2018         16.14.0.100
#
#              Android Ver
# 4812  Varies with device
# 2763          4.4 and up

# %% [markdown]
# # Numeric features in data
# 1.  Rating
# 2.  Reviews
# 3.  Size
# 4.  Installs
# 5.  Price

# %%
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 430k                     1
# 429k                     1
# 200k                     1
# 460k                     1
# 619k                     1
# Name: count, Length: 461, dtype: int64

# %%
df['Size'].isnull().sum()
# Out:
# 0

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             908
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Name: count, dtype: int64

# %%
df['Installs'].isnull().sum()
# Out:
# 0

# %%
df['Price'].value_counts()
# Out:
# Price
# 0         10041
# $0.99       148
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $19.90        1
# $1.75         1
# $14.00        1
# $4.85         1
# $1.04         1
# Name: count, Length: 92, dtype: int64

# %%
df['Price'].isnull().sum()
# Out:
# 0

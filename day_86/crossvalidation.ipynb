# %% [markdown]
# # Cross Validation

# %%
# Import libraies
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB

# %%
# Load the iris dataset
iris = load_iris()

# %% [markdown]
# # K-Fold Cross Validation

# %%
# %%time
# Define the Gaussian Naive Bayes model
gnb = GaussianNB()

# Perform K-fold cross validation with k=5
scores = cross_val_score(gnb, iris.data, iris.target, cv=5, scoring='accuracy')

# Print the accuracy of each fold and the average accuracy
print("Accuracy of each fold: ", scores)
print("Average accuracy: ", scores.mean())
print("Standard deviation: ", scores.std())
# Out:
# Accuracy of each fold:  [0.93333333 0.96666667 0.93333333 0.93333333 1.        ]
# Average accuracy:  0.9533333333333334
# Standard deviation:  0.02666666666666666
# CPU times: total: 31.2 ms
# Wall time: 19.4 ms

# %% [markdown]
# # K-Fold Cross Validation VS Train Test Spilt

# %%
# Import libraries
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
import seaborn as sns
import numpy as np

# Load the iris dataset
tips = sns.load_dataset('tips')

# Define features and target variable
X = tips[['total_bill', 'size', 'tip']]
y = tips['sex']

# Define the Gaussian Naive Bayes model
gnb = GaussianNB()

# Perform K-fold cross validation with k=5
scores = cross_val_score(gnb, X, y, cv=5, scoring='accuracy')

# Print the accuracy of each fold and the average accuracy
print("Accuracy of each fold: ", scores)
print("Average accuracy: ", scores.mean())
print("Standard deviation: ", scores.std())
# Out:
# Accuracy of each fold:  [0.55102041 0.55102041 0.59183673 0.65306122 0.54166667]
# Average accuracy:  0.5777210884353741
# Standard deviation:  0.04147568336521195

# %% [markdown]
# # Plot Cross Validation

# %%
# Plot Cross Validation
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier

# %%
# Load the iris dataset
iris = load_iris()

# %%
# Define X and y
X = iris.data
y = iris.target

# %%
# Define the Decision Tree model
clf = DecisionTreeClassifier()

# %%
# Perform K-fold cross validation with k=8
scores = cross_val_score(clf, X, y, cv=8, scoring='accuracy')

# %%
# Plot the results
plt.figure(figsize=(8, 6))
plt.plot(np.arange(1, 9), scores, marker='o', linestyle='--')
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.title('Cross Validation Accuracy')
plt.show()
